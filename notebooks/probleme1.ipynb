# %% [markdown]
# #Problème n°1

# %% [markdown]
# La bonne transmission de signaux électromagnétiques dans l'atmosphère peut dépendre de la météo. La pluie affecte notoirement les échanges entre les antennes relais des réseaux mobiles actuels. C'est une gêne, mais aussi une opportunité: l'atténuation des ondes électromagnétiques due à la pluie peut être mesurée et utilisée comme un moyen de quantifier les précipitations.
#
# Dans ce problème, on s'intéresse à la conversion de l'atténuation, définie comme un rapport entre puissance émise et puissance reçue et exprimée en dB, en un taux de pluie moyen le long de segments physiques dont les extrémités sont des paires d'antennes relais.
#
# Evidemment, d'autres éléments que le pluie, plus ou moins bien connus, peuvent influencer l'atténuation. La simulation sur laquelle nous allons travailler, qui porte sur un millier de paires d'antennes virtuelles, est construite de la façon suivante:
#
# - pour une paire d'antennes donnée, on modélise une série temporelle de taux de pluie moyen par un processus stochastique dont les paramètres dépendent entre autres de la distance qui sépare les antennes.
# - pour en tirer des atténuations, on applique à cette série les transformations suivantes:
#     - un filtre convolutif, censé modéliser l'impact du film d'eau se formant sur les antennes au cours d'un épisode de pluie.
#     - une conversion non-linéaire, tirée d'un modèle physique, est appliquée composante à composante.
#  épisode pluvieux (ce film qui s'épaissit augmente progressivement l'atténuation).
#     - un bruit haute-fréquence
#     - un bruit basse fréquence
#
# La cellules suivantes permettent de récupérer les briques de code utiles, de construire un dictionnaire contenant des identifiants de paires d'antennes (clefs) et les distances les séparant (valeurs). La dernière cellule montre des exemples de séries temporelles simulées pour quelques paires.

# %%
# Local clone
! git clone https://github.com/adragneel/exam_2025.git
! cp exam_2025/utils/utils_probleme1.py .
# Out:
# Cloning into 'exam_2025'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 63 (delta 7), reused 4 (delta 4), pack-reused 50 (from 1)
# Receiving objects: 100% (63/63), 1.42 MiB | 11.63 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# Imports
from os.path import join, isdir, isfile
from os import listdir as ls
import copy
import torch
import numpy as np
import sys
from utils_probleme1 import create_dataloader

# %%
# Dictionnaire des "distances" (générées au hasard)
idx2distance_train = {i: 0.2 +  1.8 * torch.rand((1,)).item() for i in range(0, 1000)}
idx2distance_val = {i: 0.2 +  1.8 * torch.rand((1,)).item() for i in range(1000, 1200)}

# Paramètres de la simulation
duration = 4096  # durée de la série temporelle (unité : minutes)
batch_size = 100  # taille d'un échantillon

# Création du dataloader (il contient toutes les étapes de la simulation)
# (en une époque, chaque paire d'antennes du dictionnaire idx2distance
# a été tirée exactement une fois)
trainloader = create_dataloader(duration, idx2distance_train, batch_size)

# Génération d'un batch contenant des séries temporelles
for batch_idx, (ids, dists, rain_rates, attenuations) in enumerate(trainloader):
    break

# %%
import matplotlib.pyplot as plt

for k in range(5):
  plt.figure(figsize=(10, 6))
  plt.plot(np.arange(duration), rain_rates[k], label='rain rates')
  plt.plot(np.arange(duration), attenuations[k], label='attenuations')
  plt.title(f"Attenuations et taux de pluie moyen pour la paire n°{ids[k].item():.0f} (distance: {dists[k].item():.2f} km)")
  plt.xlabel('Time (minutes)')
  plt.ylabel('DB (atten.) ou mm/h (pluie)')
  plt.ylim(-1,6)
  plt.legend()
  plt.show()

# %% [markdown]
# ## Partie I : Un réseau de neurones générique

# %% [markdown]
# # A partir des briques de base

# %% [markdown]
# Dans cette partie, on entraîne un UNet1D à faire le lien entre atténuations
# et taux de pluie. Les cellules suivantes contiennent les blocs du UNet1D et son montage :

# %%
##############################################################################################
################################     UNet 1D building blokcs    ##############################
import torch
import torch.nn as nn
import torch.nn.functional as F

class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv1d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm1d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x

class Down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(Down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool1d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class Up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=False):
        super(Up, self).__init__()
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear')
        else:
            self.up = nn.ConvTranspose1d(in_ch, in_ch, kernel_size=2, stride=2)

        self.conv = double_conv(2*in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x1.size()[2] - x2.size()[2]
        x2 = F.pad(x2, (diffX // 2, int(diffX / 2)))

        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x


class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv1d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x


################################################################################
######################################## class UNet1D ##########################

class UNet1D(nn.Module):
    def __init__(self, n_channels, n_classes, size=64):
        super(UNet1D, self).__init__()
        self.inc = inconv(n_channels, size)
        self.down1 = Down(size, 2*size)
        self.down2 = Down(2*size, 4*size)
        self.down3 = Down(4*size, 8*size)
        self.down4 = Down(8*size, 8*size)
        self.up1 = Up(8*size, 4*size)
        self.up2 = Up(4*size, 2*size)
        self.up3 = Up(2*size, size)
        self.up4 = Up(size, size)
        self.outc = outconv(size, n_classes)
        self.n_classes=n_classes

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        del x4, x5
        x = self.up2(x, x3)
        del x3
        x = self.up3(x, x2)
        del x2
        x = self.up4(x, x1)
        del x1
        x = self.outc(x)
        return   x

# %% [markdown]
# **Consignes:** \
# 1) Entraîner sur GPU un UNet 1D à restituer les taux de pluie à partir des atténuations.
# - On utilisera la MSE comme fonction de coût et comme score. Dans les deux cas, prendre une marge de deux heures au début et à la fin de la série temporelle pour éviter les effets de bord.
# - La descente de gradient stochastique sera pilotée par l'optimiseur ADAM (paramétrage standard) sur cinquante époques.
#
# 2) Tracer la courbe d'apprentissage de manière à montrer l'évolution:
# - des performances en généralisation sur de nouvelles données issues des paires d'antennes vues à l'entraînement.
# - des performances en généralisation sur des séries issues de paires d'antennes indépendantes (celles de *idx2distance_val*).
#
#
# 3) Visualiser les prédictions après apprentissage

# %%
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Hyperparameters
epochs = 50
learning_rate = 0.001  # Standard ADAM learning rate
margin = 120 # Two hours margin in minutes

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Model initialization
model = UNet1D(n_channels=1, n_classes=1).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()


# Training and validation loops
train_losses = []
val_losses = []
val_losses_new = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    for ids, dists, rain_rates, attenuations in trainloader:
        attenuations = attenuations.unsqueeze(1).to(device)
        rain_rates = rain_rates.unsqueeze(1).to(device)
        optimizer.zero_grad()

        # Forward pass
        outputs = model(attenuations[:, :, margin:-margin])
        loss = criterion(outputs, rain_rates[:, :, margin:-margin])

        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_losses.append(train_loss / len(trainloader))

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for ids, dists, rain_rates, attenuations in trainloader:
          attenuations = attenuations.unsqueeze(1).to(device)
          rain_rates = rain_rates.unsqueeze(1).to(device)
          outputs = model(attenuations[:,:,margin:-margin])
          val_loss += criterion(outputs, rain_rates[:,:,margin:-margin]).item()
    val_losses.append(val_loss / len(trainloader))

    #New validation data
    val_loss_new = 0
    # Assuming you have a valloader for idx2distance_val
    # Create valloader similar to trainloader but using idx2distance_val
    valloader = create_dataloader(duration, idx2distance_val, batch_size)
    with torch.no_grad():
      for ids, dists, rain_rates, attenuations in valloader:
        attenuations = attenuations.unsqueeze(1).to(device)
        rain_rates = rain_rates.unsqueeze(1).to(device)
        outputs = model(attenuations[:,:,margin:-margin])
        val_loss_new += criterion(outputs, rain_rates[:,:,margin:-margin]).item()
    val_losses_new.append(val_loss_new / len(valloader))
    print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, New Val Loss: {val_losses_new[-1]:.4f}')


# Plotting
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss (Training Data)')
plt.plot(val_losses_new, label='Validation Loss (New Data)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# Visualization after training
# Get a batch from the validation loader
for ids, dists, rain_rates, attenuations in valloader:
    break

model.eval()
with torch.no_grad():
    attenuations = attenuations.unsqueeze(1).to(device)
    outputs = model(attenuations[:,:,margin:-margin]).cpu().numpy()

for k in range(5):
    plt.figure(figsize=(10, 6))
    plt.plot(np.arange(duration-2*margin), rain_rates[k,0,margin:-margin], label='True Rain Rate') #Plot only the relevant part of the data
    plt.plot(np.arange(duration-2*margin), outputs[k,0,:], label='Predicted Rain Rate')
    plt.title(f"Prediction vs True Rain Rate for pair n°{ids[k].item():.0f} (distance: {dists[k].item():.2f} km)")
    plt.xlabel('Time (minutes)')
    plt.ylabel('mm/h')
    plt.legend()
    plt.show()
# Out:
# Epoch [1/50], Train Loss: 0.3186, Val Loss: 0.7916, New Val Loss: 0.7961
# Epoch [2/50], Train Loss: 0.1703, Val Loss: 0.7589, New Val Loss: 0.7866
# Epoch [3/50], Train Loss: 0.1596, Val Loss: 0.5630, New Val Loss: 0.5889
# Epoch [4/50], Train Loss: 0.1525, Val Loss: 0.4505, New Val Loss: 0.4538
# Epoch [5/50], Train Loss: 0.1490, Val Loss: 0.2456, New Val Loss: 0.2462
# Epoch [6/50], Train Loss: 0.1452, Val Loss: 0.1644, New Val Loss: 0.1651
# Epoch [7/50], Train Loss: 0.1424, Val Loss: 0.1562, New Val Loss: 0.1498
# Epoch [8/50], Train Loss: 0.1377, Val Loss: 0.1401, New Val Loss: 0.1478
# Epoch [9/50], Train Loss: 0.1365, Val Loss: 0.1472, New Val Loss: 0.1504
# Epoch [10/50], Train Loss: 0.1433, Val Loss: 0.1631, New Val Loss: 0.1654
# Epoch [11/50], Train Loss: 0.1383, Val Loss: 0.1482, New Val Loss: 0.1530
# Epoch [12/50], Train Loss: 0.1429, Val Loss: 0.1466, New Val Loss: 0.1546
# Epoch [13/50], Train Loss: 0.1388, Val Loss: 0.1410, New Val Loss: 0.1453
# Epoch [14/50], Train Loss: 0.1377, Val Loss: 0.1448, New Val Loss: 0.1423
# Epoch [15/50], Train Loss: 0.1369, Val Loss: 0.1391, New Val Loss: 0.1404
# Epoch [16/50], Train Loss: 0.1348, Val Loss: 0.1382, New Val Loss: 0.1444
# Epoch [17/50], Train Loss: 0.1333, Val Loss: 0.1389, New Val Loss: 0.1405
# Epoch [18/50], Train Loss: 0.1361, Val Loss: 0.1341, New Val Loss: 0.1375
# Epoch [19/50], Train Loss: 0.1313, Val Loss: 0.1344, New Val Loss: 0.1325
# Epoch [20/50], Train Loss: 0.1332, Val Loss: 0.1322, New Val Loss: 0.1315
# Epoch [21/50], Train Loss: 0.1331, Val Loss: 0.1334, New Val Loss: 0.1312
# Epoch [22/50], Train Loss: 0.1342, Val Loss: 0.1376, New Val Loss: 0.1432
# Epoch [23/50], Train Loss: 0.1298, Val Loss: 0.1355, New Val Loss: 0.1334
# Epoch [24/50], Train Loss: 0.1340, Val Loss: 0.1335, New Val Loss: 0.1287
# Epoch [25/50], Train Loss: 0.1303, Val Loss: 0.1333, New Val Loss: 0.1378
# Epoch [26/50], Train Loss: 0.1302, Val Loss: 0.1321, New Val Loss: 0.1363
# Epoch [27/50], Train Loss: 0.1331, Val Loss: 0.1354, New Val Loss: 0.1386
# Epoch [28/50], Train Loss: 0.1318, Val Loss: 0.1350, New Val Loss: 0.1327
# Epoch [29/50], Train Loss: 0.1350, Val Loss: 0.1365, New Val Loss: 0.1395
# Epoch [30/50], Train Loss: 0.1333, Val Loss: 0.1347, New Val Loss: 0.1352
# Epoch [31/50], Train Loss: 0.1335, Val Loss: 0.1358, New Val Loss: 0.1383
# Epoch [32/50], Train Loss: 0.1326, Val Loss: 0.1400, New Val Loss: 0.1450
# Epoch [33/50], Train Loss: 0.1345, Val Loss: 0.1411, New Val Loss: 0.1475
# Epoch [34/50], Train Loss: 0.1302, Val Loss: 0.1369, New Val Loss: 0.1361
# Epoch [35/50], Train Loss: 0.1311, Val Loss: 0.1337, New Val Loss: 0.1362
# Epoch [36/50], Train Loss: 0.1340, Val Loss: 0.1368, New Val Loss: 0.1401
# Epoch [37/50], Train Loss: 0.1335, Val Loss: 0.1322, New Val Loss: 0.1318
# Epoch [38/50], Train Loss: 0.1322, Val Loss: 0.1438, New Val Loss: 0.1484
# Epoch [39/50], Train Loss: 0.1322, Val Loss: 0.1315, New Val Loss: 0.1287
# Epoch [40/50], Train Loss: 0.1321, Val Loss: 0.1328, New Val Loss: 0.1342
# Epoch [41/50], Train Loss: 0.1324, Val Loss: 0.1309, New Val Loss: 0.1274
# Epoch [42/50], Train Loss: 0.1312, Val Loss: 0.1339, New Val Loss: 0.1344
# Epoch [43/50], Train Loss: 0.1329, Val Loss: 0.1304, New Val Loss: 0.1317
# Epoch [44/50], Train Loss: 0.1301, Val Loss: 0.1374, New Val Loss: 0.1353
# Epoch [45/50], Train Loss: 0.1319, Val Loss: 0.1290, New Val Loss: 0.1329
# Epoch [46/50], Train Loss: 0.1296, Val Loss: 0.1313, New Val Loss: 0.1313
# Epoch [47/50], Train Loss: 0.1295, Val Loss: 0.1306, New Val Loss: 0.1305
# Epoch [48/50], Train Loss: 0.1283, Val Loss: 0.1320, New Val Loss: 0.1310
# Epoch [49/50], Train Loss: 0.1301, Val Loss: 0.1322, New Val Loss: 0.1279
# Epoch [50/50], Train Loss: 0.1305, Val Loss: 0.1369, New Val Loss: 0.1297
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-5be7957da8bd> in <cell line: 89>()
#      89 for k in range(5):
#      90     plt.figure(figsize=(10, 6))
# ---> 91     plt.plot(np.arange(duration-2*margin), rain_rates[k,0,margin:-margin], label='True Rain Rate') #Plot only the relevant part of the data
#      92     plt.plot(np.arange(duration-2*margin), outputs[k,0,:], label='Predicted Rain Rate')
#      93     plt.title(f"Prediction vs True Rain Rate for pair n°{ids[k].item():.0f} (distance: {dists[k].item():.2f} km)")
#
# IndexError: too many indices for tensor of dimension 2

# %% [markdown]
# ## Partie II
#
# Dans la première partie, le modèle était générique: la specificité de la paire d'antenne n'était pas prise en compte. On se propose de le faire en combinant un réseau générique à un perceptron spécifique, de sorte que la sortie $Z$ s'exprime sous la forme: \
# $$Z = F(X, k) = f^{\tiny{Perceptron}}_{\alpha_k}(f^{\tiny{UNet}}_{\theta}(X))$$ \
#  où $f^{\tiny{UNet}}_{\theta}(.)$ représente la fonction *forward* d'un UNet et $f^{\tiny{Perceptron}}_{\alpha_k}(.)$, la fonction forward du perceptron associé à la paire d'antennes d'identifiant $k$. \
#
# Il s'agit donc en premier lieu d'adjoindre au UNet de la partie I autant de perceptrons que le jeu d'entraînement compte de paires d'antennes, ce qui se fait grâce aux lignes suivantes:

# %%
# Pour l'ajout de 1200 perceptrons à deux couches:
self.num_pairs = 1200
self.input_size_fc_layer = 5
self.hidden_size_fc_layer = 5
# Liste des premières couches
self.linears1 = nn.ModuleList([nn.Linear(self.input_size_fc_layer,
                                         self.hidden_size_fc_layer) for i in range(self.num_pairs)])
# Liste des secondes couches
self.linears2 = nn.ModuleList([nn.Linear(self.hidden_size_fc_layer,
                                         1) for i in range(self.num_pairs)])

# %% [markdown]
# **Consignes:** \
# 1) Définir une nouvelle classe de réseau en modifiant la classe UNet1D (dans utils_probleme1.py).
# Ajouter ces perceptrons au réseau.
#
# 2) Fixer *self.n_classes* de façon à ce que la sortie du UNet soit compatible avec l'entrée du perceptron.
#
# 3) Modifications de la fonction forward:
# - elle doit prendre comme arguments un batch d'entrées et un batch d'identifiants.
#
# - après les étapes propres au UNet, elle doit appliquer le perceptron d'indice k à une série provenant de la paire n°k. La cellule de code suivante fournit un exemple dont on pourra directement s'inspirer.
#
# 4) Suivre les performances en généralisation sur les paires d'antennes du jeu d'entraînement et sur les deux cents paires de validation. Commenter.

# %%
def apply_perceptron(self, UNet_output, ids):
    for i in range(ids.shape[0]):
        id = ids[i]
        # application de la première couche
        x = self.linears1[id](UNet_output[i].transpose(0,1).contiguous())
        x = self.relu(x)
        # application de la seconde couche
        x = self.linears2[id](x)
        # correction multiplicative de UNet_output
        UNet_output[i, 0] *= 1 + x.transpose(0,1).contiguous()
    return UNet_output[:,0]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import numpy as np

# Assuming utils_probleme1.py is in the same directory or accessible via sys.path
from utils_probleme1 import create_dataloader


# Modified UNet1D class with perceptrons
class UNet1D_with_perceptrons(nn.Module):
    def __init__(self, n_channels, n_classes, size=64):
        super(UNet1D_with_perceptrons, self).__init__()
        self.inc = inconv(n_channels, size)
        self.down1 = Down(size, 2 * size)
        self.down2 = Down(2 * size, 4 * size)
        self.down3 = Down(4 * size, 8 * size)
        self.down4 = Down(8 * size, 8 * size)
        self.up1 = Up(8 * size, 4 * size)
        self.up2 = Up(4 * size, 2 * size)
        self.up3 = Up(2 * size, size)
        self.up4 = Up(size, size)
        self.outc = outconv(size, n_classes) # Output should match the input size of perceptron
        self.n_classes = 5 # Set n_classes to match input_size_fc_layer

        self.num_pairs = 1200
        self.input_size_fc_layer = self.n_classes # Input size of the perceptron
        self.hidden_size_fc_layer = 5
        self.relu = nn.ReLU()

        self.linears1 = nn.ModuleList([nn.Linear(self.input_size_fc_layer,
                                                self.hidden_size_fc_layer) for _ in range(self.num_pairs)])
        self.linears2 = nn.ModuleList([nn.Linear(self.hidden_size_fc_layer,
                                                1) for _ in range(self.num_pairs)])


    def forward(self, x, ids):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        x = self.outc(x)

        # Apply Perceptron
        for i in range(ids.shape[0]):
            id = ids[i].item()
            # Application de la première couche
            perceptron_input = x[i, :, :].transpose(0, 1).contiguous() #Reshape to match the expected perceptron input
            x_perc = self.linears1[id](perceptron_input)
            x_perc = self.relu(x_perc)
            # Application de la seconde couche
            x_perc = self.linears2[id](x_perc)

            # Correction multiplicative de UNet_output
            x[i, 0, :] = x[i, 0, :] * (1 + x_perc.transpose(0, 1).contiguous()) # Adjust output shapes

        return x[:, 0, :]

# %%
# Hyperparameters
epochs = 50
learning_rate = 0.001
margin = 120

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Model initialization
model = UNet1D_with_perceptrons(n_channels=1, n_classes=5).to(device) # n_classes set to 5 as per the modified class
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.MSELoss()

# Training and validation loops
train_losses = []
val_losses = []
val_losses_new = []

for epoch in range(epochs):
    model.train()
    train_loss = 0
    for ids, dists, rain_rates, attenuations in trainloader:
        attenuations = attenuations.unsqueeze(1).to(device)
        rain_rates = rain_rates.to(device)
        optimizer.zero_grad()

        outputs = model(attenuations[:,:, margin:-margin], ids.to(device))
        loss = criterion(outputs, rain_rates[:, margin:-margin])

        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_losses.append(train_loss / len(trainloader))

    model.eval()
    val_loss = 0
    with torch.no_grad():
        for ids, dists, rain_rates, attenuations in trainloader:
            attenuations = attenuations.unsqueeze(1).to(device)
            rain_rates = rain_rates.to(device)
            outputs = model(attenuations[:,:,margin:-margin], ids.to(device))
            val_loss += criterion(outputs, rain_rates[:,margin:-margin]).item()
    val_losses.append(val_loss / len(trainloader))

    val_loss_new = 0
    valloader = create_dataloader(duration, idx2distance_val, batch_size)
    with torch.no_grad():
        for ids, dists, rain_rates, attenuations in valloader:
            attenuations = attenuations.unsqueeze(1).to(device)
            rain_rates = rain_rates.to(device)
            outputs = model(attenuations[:,:,margin:-margin], ids.to(device))
            val_loss_new += criterion(outputs, rain_rates[:,margin:-margin]).item()
    val_losses_new.append(val_loss_new / len(valloader))

    print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}, New Val Loss: {val_losses_new[-1]:.4f}')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss (Training Data)')
plt.plot(val_losses_new, label='Validation Loss (New Data)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# %% [markdown]
# # il n'y a pas d'execution car pas de gpu

# %% [markdown]
# ## Partie III
#
# La solution proposée dans la partie II a un défaut: les performances chutent sur les paires d'antennes qui n'ont pas été rencontrées pendant l'entraînement. Pour le corriger, on se propose de suivre la méthode suivante:
# - ajouter un perceptron "générique" de même architecture que les perceptrons spécifiques.
# - entraîner le réseau de la partie II en remplaçant une fois sur quatre l'identifiant de la paire d'antennes par l'indice du perceptron générique.
# - après cinquante époques, geler les poids de la partie générique et prolonger l'apprentissage des perceptrons spécifiques sur une vingtaine d'époque.
#
# **Consignes:** \
#
# 1) Mettre en oeuvre cette méthode
#
# 2) Conclure sur son efficacité
